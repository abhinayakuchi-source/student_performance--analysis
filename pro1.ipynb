# %%
import pandas as pd

data = {
    'Student':['A','B','C','D','E'],
    'Marks':[80,70,90,75,85]
}

df = pd.DataFrame(data)

print(df)
print(df.describe())
print(df.isnull().sum())
# Out:
#   Student  Marks
# 0       A     80
# 1       B     70
# 2       C     90
# 3       D     75
# 4       E     85
#            Marks
# count   5.000000
# mean   80.000000
# std     7.905694
# min    70.000000
# 25%    75.000000
# 50%    80.000000
# 75%    85.000000
# max    90.000000
# Student    0
# Marks      0
# dtype: int64
